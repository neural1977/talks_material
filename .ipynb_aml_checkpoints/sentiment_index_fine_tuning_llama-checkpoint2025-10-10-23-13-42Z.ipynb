# %% [markdown]
# # **Sentiment Index Generation: Llama**

# %% [markdown]
# # **All Installations**

# %%
# %pip install transformers datasets peft accelerate evaluate torch --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install python-dotenv
# Out:
# Requirement already satisfied: python-dotenv in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (6.4.0)
# Requirement already satisfied: narwhals>=1.15.1 in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from plotly) (2.10.2)
# Requirement already satisfied: packaging in /anaconda/envs/jupyter_env/lib/python3.10/site-packages (from plotly) (24.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import platform

def data_download(file_to_download, gdrive_code, OS, uncompress = True):
  if not os.path.exists(file_to_download):
    os.system('gdown --id "'+gdrive_code+'" --output '+file_to_download)
    if OS == "Linux" and uncompress:
        os.system('unzip -o -n "./'+file_to_download+'" -d "./"')
    return True
  else:
    return None

OS = platform.system()

out = data_download("./Sentiment_Dataset.zip", "1OEQpkzN6HMcZc3yPg8G0ahvh6lOCMlIR", OS)
# Out:
# /anaconda/envs/azureml_py38/lib/python3.10/site-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1OEQpkzN6HMcZc3yPg8G0ahvh6lOCMlIR
# From (redirected): https://drive.google.com/uc?id=1OEQpkzN6HMcZc3yPg8G0ahvh6lOCMlIR&confirm=t&uuid=3c2baebc-bee3-4c42-869b-d32035cd7cfc
# To: /mnt/batch/tasks/shared/LS_root/mounts/clusters/frpuglie2-a100single/code/Users/frpuglie/talks_material/Sentiment_Dataset.zip
# 100%|██████████| 1.21G/1.21G [00:09<00:00, 128MB/s]
# Archive:  ././Sentiment_Dataset.zip
#    creating: ./Sentiment_Dataset/
#  extracting: ./Sentiment_Dataset/.env
#    creating: ./Sentiment_Dataset/2020_index_tweets_set/
#    creating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-01.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-02.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-03.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-04.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-05.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-06.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-07.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-08.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-09.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-10.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-11.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-12.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-13.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-14.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-15.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-16.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-17.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-18.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-19.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-20.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-21.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-22.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-23.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-24.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-25.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-26.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-27.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-28.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-29.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood/2020-04-30.csv
#    creating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-01.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-02.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-03.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-04.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-05.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-06.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-07.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-08.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-09.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-10.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-11.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-12.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-13.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-14.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-15.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-16.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-17.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-18.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-19.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-20.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-21.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-22.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-23.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-24.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-25.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-26.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-27.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-28.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-02-29.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood/2020-03-01.csv
#    creating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-01.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-02.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-03.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-04.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-05.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-06.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-07.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-08.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-09.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-10.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-11.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-12.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-13.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-14.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-15.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-16.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-17.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-18.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-19.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-20.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-21.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-22.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-23.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-24.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-25.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-26.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-27.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-28.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-29.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-30.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood/2020-01-31.csv
#    creating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-02.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-03.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-04.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-05.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-06.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-07.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-08.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-09.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-10.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-11.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-12.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-13.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-14.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-15.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-16.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-17.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-18.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-19.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-20.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-21.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-22.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-23.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-24.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-25.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-26.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-27.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-28.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-29.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-30.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood/2020-03-31.csv
#    creating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-01.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-02.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-03.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-04.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-05.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-06.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-07.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-08.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-09.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-10.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-11.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-12.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-13.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-14.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-15.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-16.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-17.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-18.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-19.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-20.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-21.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-22.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-23.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-24.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-25.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-26.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-27.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-28.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-29.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-30.csv
#   inflating: ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood/2020-05-31.csv
#   inflating: ./Sentiment_Dataset/irony_dataset.txt
#   inflating: ./Sentiment_Dataset/training_set.csv

# %% [markdown]
# # **All Imports**

# %%
#General
import timeit
import torch
import random
import calendar
import numpy as np
import pandas as pd
from dotenv import load_dotenv
import plotly.express as px
import shutil

# LLMs
import evaluate
from datasets import Dataset
from transformers import (
    AutoConfig,
    AutoTokenizer,
    AutoModelForSequenceClassification,
    TrainingArguments,
    Trainer,
)
from peft import LoraConfig, get_peft_model

# Machine Learning
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %% [markdown]
# # **All Globals**

# %%
seed = 42
dataset_limit = 3000
sentiment_index_limit = 100
n_tweets_per_day = 1000
n_epochs = 10
moving_average_window = 7
llm_model_parameters_number = '1B'                # number of billion parameters of the LLM mode, 1B is the smaller llama3.2 1 billion of parameters
#model_name = f"meta-llama/Llama-3.2-{llm_model_parameters_number}-Instruct"
model_name = f"meta-llama/Llama-3.2-{llm_model_parameters_number}"
dataset_path = "./Sentiment_Dataset/"
chart_from_local = False

# %% [markdown]
# # **Initializations**

# %%
os.environ["WANDB_MODE"] = "disabled"

start_global_time = timeit.default_timer()

# !mv "{dataset_path}.env" ./
random.seed(seed)
np.random.seed(seed)

load_dotenv()
# Out:
# True

# %% [markdown]
# # **Functions Definition**

# %%
def tokenize_function(example):
    return tokenizer(
        example["text"],
        padding="max_length",
        truncation=True,
        max_length=256
    )

def df_predictions(df, tokenized_df, trainer, label_mapping):
    predictions = trainer.predict(tokenized_df)
    predicted_labels = predictions.predictions.argmax(-1)
    label_mapping = np.load("labels_mapping.npy", allow_pickle=True).item()
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}
    predicted_sentiment = [reverse_label_mapping[label] for label in predicted_labels]
    df['predicted_sentiment'] = predicted_sentiment
    return df

def month_sort_key(month_dir):
    month_name = os.path.basename(month_dir).split('_')[0]
    try:
        return list(calendar.month_name).index(month_name.capitalize())
    except ValueError:
        return 0

# %% [markdown]
# # **Dataset Reading**

# %%
irony_df = pd.read_csv("./Sentiment_Dataset/irony_dataset.txt", header=None).rename(columns={0: 'text'})["text"].to_frame()

# %%
df = pd.read_csv("./Sentiment_Dataset/training_set.csv", sep = ";")
df = df[["text", "pol"]].dropna()         # select the columns interesting for us and drop rows with NaN

# %%
if dataset_limit is not None:
    df = df.sample(dataset_limit).reset_index(drop=True)

# %%
print("Numnber of data-points:", len(df))
# Out:
# Numnber of data-points: 3000

# %%
df.head()
# Out:
#                                                 text  pol
# 0  Arbasina/Giavazzi sul Corriere a proposito del...  0.0
# 1  il trading è un amp azienda ecco come risparmi...  1.0
# 2  RT TAG mi hanno unfollowato in massa, mortacci...  2.0
# 3  modalità prezzi e biglietti per la gara al man...  0.0
# 4  donnastef shop t shirt gonna borsa spedizione ...  0.0

# %% [markdown]
# 1: 'Positive', 2: 'Negative', 0: 'Neutral'

# %%
print("Number of classes", df["pol"].nunique())
print("Types of classes", df["pol"].unique())
# Out:
# Number of classes 3
# Types of classes [0. 1. 2.]

# %% [markdown]
# # **Dataset Recoding**

# %%
df['pol'] = df['pol'].map({1: 'Positive', 2: 'Negative', 0: 'Neutral'})
df = df.rename(columns={'pol': 'label'})

# %%
df.head()
# Out:
#                                                 text     label
# 0  Arbasina/Giavazzi sul Corriere a proposito del...   Neutral
# 1  il trading è un amp azienda ecco come risparmi...  Positive
# 2  RT TAG mi hanno unfollowato in massa, mortacci...  Negative
# 3  modalità prezzi e biglietti per la gara al man...   Neutral
# 4  donnastef shop t shirt gonna borsa spedizione ...   Neutral

# %% [markdown]
# # **Label Conversion**

# %%
label_encoder = LabelEncoder()
df['label'] = label_encoder.fit_transform(df['label'])
label_mapping = dict(zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)))
np.save("labels_mapping.npy", label_mapping)
print("Label mapping:", label_mapping)
# Out:
# Label mapping: {'Negative': np.int64(0), 'Neutral': np.int64(1), 'Positive': np.int64(2)}

# %% [markdown]
# # **Train-Test Split**

# %%
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])

# %% [markdown]
# # **Dataset Conversion for Transformers**

# %%
irony_dataset = Dataset.from_pandas(irony_df)
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)
unique_labels = train_dataset.unique('label')
num_labels = len(unique_labels)
print("Number of Labels withing the Training Set:", len(unique_labels))
# Out:
# Number of Labels withing the Training Set: 3

# %%
train_dataset
# Out:
# Dataset({
#     features: ['text', 'label', '__index_level_0__'],
#     num_rows: 2400
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text', 'label', '__index_level_0__'],
#     num_rows: 600
# })

# %% [markdown]
# # **Tokenization and Padding**

# %%
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token

# %%
tokenized_irony = irony_dataset.map(tokenize_function, batched=True)
tokenized_train = train_dataset.map(tokenize_function, batched=True)
tokenized_test = test_dataset.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/71 [00:00<?, ? examples/s]
# Map:   0%|          | 0/2400 [00:00<?, ? examples/s]
# Map:   0%|          | 0/600 [00:00<?, ? examples/s]

# %% [markdown]
# ## **Load the LLM Model**

# %%
model = AutoModelForSequenceClassification.from_pretrained(
    model_name,
    num_labels=num_labels,
    torch_dtype=torch.bfloat16,
    device_map="auto"                           # auto: for 1 GPU, and balanced_low_0 for multi-gput
)
# Out:
# `torch_dtype` is deprecated! Use `dtype` instead!
# Some weights of LlamaForSequenceClassification were not initialized from the model checkpoint at meta-llama/Llama-3.2-1B and are newly initialized: ['score.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# # **Definition of QLora**

# %%
# === 7. Applica LoRA (fine-tuning efficiente) ===
peft_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.05,
    bias="none",
    task_type="SEQ_CLS"
)

model = get_peft_model(model, peft_config)

# %% [markdown]
#  # **Metrics Definition**

# %%
accuracy = evaluate.load("accuracy")

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    preds = predictions.argmax(-1)
    return accuracy.compute(predictions=preds, references=labels)

# %% [markdown]
# # **Training Parameters Definition**

# %%
training_args = TrainingArguments(
    output_dir="./llama3_finetuned",
    per_device_train_batch_size=2,
    per_device_eval_batch_size=2,
    eval_strategy="epoch",
    save_strategy="epoch",
    num_train_epochs=n_epochs,
    learning_rate=2e-5,
    logging_dir="./logs",
    logging_steps=50,
    load_best_model_at_end=True,
    report_to=[]  # Disactivate the W&B
)

# %% [markdown]
# # **Training Model Definition**

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_test,
    tokenizer=tokenizer,
    compute_metrics=compute_metrics,
)
# Out:
# /tmp/ipykernel_4648/3389762461.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(
# The model is already on multiple devices. Skipping the move to device specified in `args`.

# %%
#irony_df = df_predictions(irony_df, tokenized_irony, trainer, label_mapping)

# %%
#irony_df

# %%
'''
negative_count = irony_df[irony_df['predicted_sentiment'] == 'Negative'].shape[0]
total_count = irony_df.shape[0]
percentage_negative = (negative_count / total_count) * 100

print(f"Percentage of negative sentiments detected in irony_df after training: {percentage_negative:.2f}%")
'''
# Out:
# '\nnegative_count = irony_df[irony_df[\'predicted_sentiment\'] == \'Negative\'].shape[0]\ntotal_count = irony_df.shape[0]\npercentage_negative = (negative_count / total_count) * 100\n\nprint(f"Percentage of negative sentiments detected in irony_df after training: {percentage_negative:.2f}%")\n'

# %% [markdown]
# # **Model Training**

# %%
start_time = timeit.default_timer()
trainer.train()
print("Elapsed Training Time: ", timeit.default_timer() - start_time)
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'pad_token_id': 128001}.
#     <div>
#
#       <progress value='12000' max='12000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [12000/12000 13:25, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.956700</td>
#       <td>0.968241</td>
#       <td>0.630000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.969200</td>
#       <td>1.268231</td>
#       <td>0.695000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.763600</td>
#       <td>1.133078</td>
#       <td>0.715000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.619300</td>
#       <td>1.488602</td>
#       <td>0.723333</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>1.027100</td>
#       <td>1.486402</td>
#       <td>0.718333</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.884900</td>
#       <td>1.629036</td>
#       <td>0.713333</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.581000</td>
#       <td>1.860713</td>
#       <td>0.701667</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.468800</td>
#       <td>1.922889</td>
#       <td>0.705000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.208900</td>
#       <td>1.935790</td>
#       <td>0.698333</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.268400</td>
#       <td>1.955863</td>
#       <td>0.703333</td>
#     </tr>
#   </tbody>
# </table><p>
# Elapsed Training Time:  806.4149403800002

# %% [markdown]
# # **Model Evaluation**

# %%
results = trainer.evaluate()
print(f"\n✅ Accuracy sul test set: {results['eval_accuracy']:.4f}")
# Out:
# ✅ Accuracy sul test set: 0.6300

# %% [markdown]
# # **Model Testing on Irony Dataset**

# %%
irony_df = df_predictions(irony_df, tokenized_irony, trainer, label_mapping)

# %%
irony_df
# Out:
#                                                  text predicted_sentiment
# 0   Oh, che meraviglia, ancora una volta il treno ...            Positive
# 1   La mia giornata è stata così fantastica che st...            Positive
# 2   Sono così grato al mio capo per avermi assegna...            Positive
# 3   Wow, sono così felice che il mio vicino abbia ...            Positive
# 4   Adoro quando il mio computer decide di bloccar...            Negative
# ..                                                ...                 ...
# 66  Finalmente ho trovato il tempo per riposarmi e...            Positive
# 67  La mia squadra del cuore ha appena pareggiato ...            Positive
# 68  Oh, fantastico, ho dimenticato il mio portafog...            Positive
# 69  Sono così fortunato ad avere una sveglia così ...            Positive
# 70  Adoro quando il mio telefono decide di impazzi...            Positive
#
# [71 rows x 2 columns]

# %%
negative_count = irony_df[irony_df['predicted_sentiment'] == 'Negative'].shape[0]
total_count = irony_df.shape[0]
percentage_negative = (negative_count / total_count) * 100

print(f"Percentage of negative sentiments detected in irony_df after training: {percentage_negative:.2f}%")
# Out:
# Percentage of negative sentiments detected in irony_df after training: 18.31%

# %% [markdown]
# # **Sentiment Index Creation**

# %% [markdown]
# ## **Tweets Production Set Reading**

# %%
start_time = timeit.default_timer()
all_dataframes = []
directory_path = "./Sentiment_Dataset/2020_index_tweets_set/"
month_directories = [os.path.join(directory_path, d) for d in os.listdir(directory_path) if os.path.isdir(os.path.join(directory_path, d))]
month_directories.sort(key=month_sort_key) # Sort the directories chronologically

for month_dir in month_directories:
    print("Month File: ", month_dir)
    csv_files = [f for f in os.listdir(month_dir) if f.endswith('.csv')]
    # Sort csv files by date in filename
    csv_files.sort(key=lambda x: x.split('.')[0])
    for file_name in csv_files:
        print("Day File: ", file_name)
        file_path = os.path.join(month_dir, file_name)
        try:
            df = pd.read_csv(file_path, encoding='utf-8', nrows = n_tweets_per_day, sep = ';')
        except UnicodeDecodeError:
            df = pd.read_csv(file_path, encoding='latin1', nrows = n_tweets_per_day, sep = ';')
        all_dataframes.append((file_name.split('.')[0], df["testo"]))
print("Elapsed Tweets Reading time: ", timeit.default_timer() - start_time)
# Out:
# Month File:  ./Sentiment_Dataset/2020_index_tweets_set/jan_tweets_social_mood
# Day File:  2020-01-01.csv
# Day File:  2020-01-02.csv
# Day File:  2020-01-03.csv
# Day File:  2020-01-04.csv
# Day File:  2020-01-05.csv
# Day File:  2020-01-06.csv
# Day File:  2020-01-07.csv
# Day File:  2020-01-08.csv
# Day File:  2020-01-09.csv
# Day File:  2020-01-10.csv
# Day File:  2020-01-11.csv
# Day File:  2020-01-12.csv
# Day File:  2020-01-13.csv
# Day File:  2020-01-14.csv
# Day File:  2020-01-15.csv
# Day File:  2020-01-16.csv
# Day File:  2020-01-17.csv
# Day File:  2020-01-18.csv
# Day File:  2020-01-19.csv
# Day File:  2020-01-20.csv
# Day File:  2020-01-21.csv
# Day File:  2020-01-22.csv
# Day File:  2020-01-23.csv
# Day File:  2020-01-24.csv
# Day File:  2020-01-25.csv
# Day File:  2020-01-26.csv
# Day File:  2020-01-27.csv
# Day File:  2020-01-28.csv
# Day File:  2020-01-29.csv
# Day File:  2020-01-30.csv
# Day File:  2020-01-31.csv
# Month File:  ./Sentiment_Dataset/2020_index_tweets_set/february_tweets_social_mood
# Day File:  2020-02-01.csv
# Day File:  2020-02-02.csv
# Day File:  2020-02-03.csv
# Day File:  2020-02-04.csv
# Day File:  2020-02-05.csv
# Day File:  2020-02-06.csv
# Day File:  2020-02-07.csv
# Day File:  2020-02-08.csv
# Day File:  2020-02-09.csv
# Day File:  2020-02-10.csv
# Day File:  2020-02-11.csv
# Day File:  2020-02-12.csv
# Day File:  2020-02-13.csv
# Day File:  2020-02-14.csv
# Day File:  2020-02-15.csv
# Day File:  2020-02-16.csv
# Day File:  2020-02-17.csv
# Day File:  2020-02-18.csv
# Day File:  2020-02-19.csv
# Day File:  2020-02-20.csv
# Day File:  2020-02-21.csv
# Day File:  2020-02-22.csv
# Day File:  2020-02-23.csv
# Day File:  2020-02-24.csv
# Day File:  2020-02-25.csv
# Day File:  2020-02-26.csv
# Day File:  2020-02-27.csv
# Day File:  2020-02-28.csv
# Day File:  2020-02-29.csv
# Day File:  2020-03-01.csv
# Month File:  ./Sentiment_Dataset/2020_index_tweets_set/march_tweets_social_mood
# Day File:  2020-03-02.csv
# Day File:  2020-03-03.csv
# Day File:  2020-03-04.csv
# Day File:  2020-03-05.csv
# Day File:  2020-03-06.csv
# Day File:  2020-03-07.csv
# Day File:  2020-03-08.csv
# Day File:  2020-03-09.csv
# Day File:  2020-03-10.csv
# Day File:  2020-03-11.csv
# Day File:  2020-03-12.csv
# Day File:  2020-03-13.csv
# Day File:  2020-03-14.csv
# Day File:  2020-03-15.csv
# Day File:  2020-03-16.csv
# Day File:  2020-03-17.csv
# Day File:  2020-03-18.csv
# Day File:  2020-03-19.csv
# Day File:  2020-03-20.csv
# Day File:  2020-03-21.csv
# Day File:  2020-03-22.csv
# Day File:  2020-03-23.csv
# Day File:  2020-03-24.csv
# Day File:  2020-03-25.csv
# Day File:  2020-03-26.csv
# Day File:  2020-03-27.csv
# Day File:  2020-03-28.csv
# Day File:  2020-03-29.csv
# Day File:  2020-03-30.csv
# Day File:  2020-03-31.csv
# Month File:  ./Sentiment_Dataset/2020_index_tweets_set/april_tweets_social_mood
# Day File:  2020-04-01.csv
# Day File:  2020-04-02.csv
# Day File:  2020-04-03.csv
# Day File:  2020-04-04.csv
# Day File:  2020-04-05.csv
# Day File:  2020-04-06.csv
# Day File:  2020-04-07.csv
# Day File:  2020-04-08.csv
# Day File:  2020-04-09.csv
# Day File:  2020-04-10.csv
# Day File:  2020-04-11.csv
# Day File:  2020-04-12.csv
# Day File:  2020-04-13.csv
# Day File:  2020-04-14.csv
# Day File:  2020-04-15.csv
# Day File:  2020-04-16.csv
# Day File:  2020-04-17.csv
# Day File:  2020-04-18.csv
# Day File:  2020-04-19.csv
# Day File:  2020-04-20.csv
# Day File:  2020-04-21.csv
# Day File:  2020-04-22.csv
# Day File:  2020-04-23.csv
# Day File:  2020-04-24.csv
# Day File:  2020-04-25.csv
# Day File:  2020-04-26.csv
# Day File:  2020-04-27.csv
# Day File:  2020-04-28.csv
# Day File:  2020-04-29.csv
# Day File:  2020-04-30.csv
# Month File:  ./Sentiment_Dataset/2020_index_tweets_set/may_tweets_social_mood
# Day File:  2020-05-01.csv
# Day File:  2020-05-02.csv
# Day File:  2020-05-03.csv
# Day File:  2020-05-04.csv
# Day File:  2020-05-05.csv
# Day File:  2020-05-06.csv
# Day File:  2020-05-07.csv
# Day File:  2020-05-08.csv
# Day File:  2020-05-09.csv
# Day File:  2020-05-10.csv
# Day File:  2020-05-11.csv
# Day File:  2020-05-12.csv
# Day File:  2020-05-13.csv
# Day File:  2020-05-14.csv
# Day File:  2020-05-15.csv
# Day File:  2020-05-16.csv
# Day File:  2020-05-17.csv
# Day File:  2020-05-18.csv
# Day File:  2020-05-19.csv
# Day File:  2020-05-20.csv
# Day File:  2020-05-21.csv
# Day File:  2020-05-22.csv
# Day File:  2020-05-23.csv
# Day File:  2020-05-24.csv
# Day File:  2020-05-25.csv
# Day File:  2020-05-26.csv
# Day File:  2020-05-27.csv
# Day File:  2020-05-28.csv
# Day File:  2020-05-29.csv
# Day File:  2020-05-30.csv
# Day File:  2020-05-31.csv
# Elapsed Tweets Reading time:  6.922463959000197

# %%
all_dataframes[0]
# Out:
# ('2020-01-01',
#  0      per la cronaca canova fu uno dei primi monumen...
#  1      l opera d arte del giorno antonio canova amore...
#  2      rt borghi claudio iniziare l anno con uno che ...
#  3      tutta salute approda in seconda serata per ini...
#  4      un anno di lavoro se permetti lo auguro io a t...
#                               ...
#  995    ruttosporc i coniglietti che cancellano il twe...
#  996    chi vota cazzola vota bonaccini in emilia roma...
#  997    cominciamo il con una bella adozione questo ca...
#  998    ma si deve ancora assistere a queste vergognos...
#  999    il papa niente maiale al pranzo con i poveri c...
#  Name: testo, Length: 1000, dtype: object)

# %% [markdown]
# ## **Sentiment Index Predictions**

# %%
start_time = timeit.default_timer()
daily_sentiment_counts = []

i = 0
for date, series in all_dataframes:
    print(f"Computing day {date}")
    df = series.to_frame(name='text')
    dataset = Dataset.from_pandas(df)
    tokenized_dataset = dataset.map(tokenize_function, batched=True)
    predictions = trainer.predict(tokenized_dataset)
    predicted_labels = predictions.predictions.argmax(-1)
    label_mapping = np.load("labels_mapping.npy", allow_pickle=True).item()
    reverse_label_mapping = {v: k for k, v in label_mapping.items()}
    predicted_sentiment = [reverse_label_mapping[label] for label in predicted_labels]
    positive_count = predicted_sentiment.count('Positive')
    negative_count = predicted_sentiment.count('Negative')
    neutral_count = predicted_sentiment.count('Neutral')
    daily_sentiment_counts.append({'date': date, 'positive': positive_count, 'negative': negative_count, "sentiment_index": (positive_count-negative_count)/(positive_count+neutral_count+negative_count)})
    i += 1
    if i>=sentiment_index_limit and sentiment_index_limit is not None:
      break

sentiment_counts_df = pd.DataFrame(daily_sentiment_counts)
#display(sentiment_counts_df)
print("Elapsed Sentimet Index Predictions time: ", timeit.default_timer() - start_time)
# Out:
# Computing day 2020-01-01
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Computing day 2020-01-02
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Computing day 2020-01-03
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
# Computing day 2020-01-04
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='109' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [109/500 00:02 < 00:08, 44.69 it/s]
#     </div>

# %%
if chart_from_local is False:
  sentiment_counts_df.to_excel("./sentiment_index.xlsx")

# %% [markdown]
# ## **Plot of the Setiment Index**

# %%
if chart_from_local is True:
  sentiment_counts_df = pd.read_excel("./sentiment_index.xlsx")

# %%
sentiment_counts_df['rolling_avg'] = sentiment_counts_df['sentiment_index'].rolling(window=moving_average_window).mean()

fig = px.line(sentiment_counts_df, x='date', y='sentiment_index', title='Daily Sentiment Index')
fig.add_scatter(x=sentiment_counts_df['date'], y=sentiment_counts_df['rolling_avg'], mode='lines', name='7-Day Rolling Average', line=dict(color='red'))
fig.update_layout(xaxis_title='Date', yaxis_title='Sentiment Index')
fig.update_xaxes(tickformat="%Y-%m-%d", tickangle=45) # Format date and rotate labels
fig.write_html("./sentiment_index_plot.html")
#fig.write_image("./sentiment_index_plot.jpeg")
fig.show()

# %%
if os.path.exists("./Sentiment_Dataset"):
    shutil.rmtree("Sentiment_Dataset")
    print("Removed Sentiment_Dataset directory.")

if os.path.exists("./llama3_finetuned"):
    shutil.rmtree("llama3_finetuned")
    print("Removed llama3_finetuned directory.")

if os.path.exists("./Sentiment_Dataset.zip"):
    os.remove("Sentiment_Dataset.zip")
    print("Removed Sentiment_Dataset.zip file.")

# %%
print("Global Program Execution time: ", timeit.default_timer() - start_global_time)
